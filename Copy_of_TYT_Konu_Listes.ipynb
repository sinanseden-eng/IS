# %% [markdown]
# <a href="https://colab.research.google.com/github/sinanseden-eng/IS/blob/main/Copy_of_TYT_Konu_Listes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.apps.presentations as presentations

# TYT konularını ve zorluk derecelerini içeren veri yapısı
tyt_konulari = {
    "Türkçe":,
       ,
        ["Cümlede Anlam", "Orta"],
        ["Paragrafta Anlam", "Orta"],
       ,
       ,
       ,
        ["Noktalama İşaretleri", "Orta"],
       ,
       ,
        ["Fiiller", "Orta"],
        ["Fiilimsiler", "Zor"],
        ["Ek Fiil", "Orta"],
        ["Fiilde Çatı", "Zor"],
        ["Cümlenin Öğeleri", "Zor"],
       ,
       ,
    "Matematik":,
       ,
       ,
       ,
       ,
       ,
       ,
       ,
       ,
       ,
        ["Çarpanlara Ayırma", "Orta"],
        ["Oran - Orantı", "Kolay"],
       ,
        ["Problemler", "Zor"],
        ["Kümeler", "Kolay"],
        ["Mantık", "Orta"],
        ["Fonksiyonlar", "Zor"],
        ["Polinomlar", "Zor"],
       ,
        ["Olasılık", "Zor"],
        ["Veri ve İstatistik", "Kolay"],
       ,
        ["Özel Üçgenler", "Orta"],
       ,
       ,
       ,
        ["Analitik Geometri", "Zor"],
        ["Katı Cisimler", "Zor"],
    "Sosyal Bilimler":,
       ,
        ["İlk Çağ Uygarlıkları", "Orta"],
       ,
        ["Milli Mücadele", "Orta"],
       ,
       ,
       ,
       ,
       ,
       ,
        ["Felsefenin Alanı", "Kolay"],
       ,
        ["Ahlak Felsefesi", "Kolay"],
       ,
        ["İslam ve İbadet", "Kolay"],
        ["Hz. Muhammed'in Hayatı", "Kolay"],
    "Fen Bilimleri":,
       ,
        ["Madde ve Özellikleri", "Kolay"],
        ["Kuvvet ve Hareket", "Orta"],
       ,
        ["Elektrik", "Zor"],
        ["Optik", "Zor"],
       ,
       ,
        ["Maddenin Halleri", "Kolay"],
       ,
        ["Canlıların Ortak Özellikleri", "Kolay"],
        ["Hücre ve Organelleri", "Orta"],
       ,
        ["Kalıtımın Genel İlkeleri", "Zor"],
        ["Ekosistem Ekolojisi", "Kolay"],
}

# Sunum için slaytları oluştur
slides =
for ders, konular in tyt_konulari.items():
    # Her ders için bir başlık ve tablo içeren bir slayt oluştur
    slide = presentations.Slide(
        title=f"TYT {ders} Konuları ve Zorluk Dereceleri",
        body=presentations.Table(
            headers=konular,
            rows=konular[1:]
        )
    )
    slides.append(slide)

# Google Slides sunumunu oluştur
presentation = presentations.create(
    title="TYT Konu Listesi ve Zorluk Dereceleri",
    slides=slides
)

# Oluşturulan sunumun bilgilerini yazdır
print(presentation)
# Out:
#   File "/tmp/ipython-input-2004641569.py", line 5
#     "Türkçe":,
#             ^
# SyntaxError: expression expected after dictionary key and ':'
